# %%
import pandas as pd

# %%
mental_health_survey = pd.read_csv("survey.csv")

# %%
print (mental_health_survey)
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
mental_health_df=pd.read_csv ("survey.csv")
print (mental_health_df.head())
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
mental_health_df.pop('no_employees')
mental_health_df
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
#      family_history treatment work_interfere remote_work  ...  \
# ...

# %%
mental_health_df.pop('Gender')
mental_health_df
# Out:
#                 Timestamp  Age         Country state self_employed  \
# 0     2014-08-27 11:29:31   37   United States    IL           NaN
# 1     2014-08-27 11:29:37   44   United States    IN           NaN
# 2     2014-08-27 11:29:44   32          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31   United States    TX           NaN
# ...                   ...  ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32   United States    IL            No
# 1256  2015-11-07 12:36:58   34   United States    CA            No
# 1257  2015-11-30 21:25:06   46   United States    NC            No
# 1258  2016-02-01 23:04:31   25   United States    IL            No
#
#      family_history treatment work_interfere remote_work tech_company  ...  \
# 0                No       Yes          Often          No          Yes  ...
# ...

# %%
mental_health_df.pop('obs_consequence')
mental_health_df
# Out:
#                 Timestamp  Age         Country state self_employed  \
# 0     2014-08-27 11:29:31   37   United States    IL           NaN
# 1     2014-08-27 11:29:37   44   United States    IN           NaN
# 2     2014-08-27 11:29:44   32          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31   United States    TX           NaN
# ...                   ...  ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32   United States    IL            No
# 1256  2015-11-07 12:36:58   34   United States    CA            No
# 1257  2015-11-30 21:25:06   46   United States    NC            No
# 1258  2016-02-01 23:04:31   25   United States    IL            No
#
#      family_history treatment work_interfere remote_work tech_company  ...  \
# 0                No       Yes          Often          No          Yes  ...
# ...

# %%
mental_health_df.drop(['comments','supervisor','coworkers','anonymity','mental_health_consequence','mental_health_interview','self_employed','work_interfere','mental_vs_physical','phys_health_consequence','phys_health_interview'],axis=1)
# Out:
#                 Timestamp  Age         Country state family_history treatment  \
# 0     2014-08-27 11:29:31   37   United States    IL             No       Yes
# 1     2014-08-27 11:29:37   44   United States    IN             No        No
# 2     2014-08-27 11:29:44   32          Canada   NaN             No        No
# 3     2014-08-27 11:29:46   31  United Kingdom   NaN            Yes       Yes
# 4     2014-08-27 11:30:22   31   United States    TX             No        No
# ...                   ...  ...             ...   ...            ...       ...
# 1254  2015-09-12 11:17:21   26  United Kingdom   NaN             No       Yes
# 1255  2015-09-26 01:07:35   32   United States    IL            Yes       Yes
# 1256  2015-11-07 12:36:58   34   United States    CA            Yes       Yes
# 1257  2015-11-30 21:25:06   46   United States    NC             No        No
# 1258  2016-02-01 23:04:31   25   United States    IL            Yes       Yes
#
# ...

# %%
mental_health_df.to_csv("new_mentalhealth_survey")
